# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

rcParams['figure.figsize'] = 20,10
# Out:
# Using TensorFlow backend.

# %%
# Read in V_nn_df.csv and drop na and unneeded columns

V_NN_df = pd.read_csv('resources/V_nn_df.csv')
V_NN = V_NN_df.drop(columns = ['Unnamed: 0'])
V_NN = V_NN.dropna(inplace=False)

V_NN.count()
# Out:
# Date        1345
# Open        1345
# High        1345
# Low         1345
# Close       1345
# Volume      1345
# Dividend    1345
# dtype: int64

# %%
# Plot Closing Prices

plt.figure(figsize=(28,14))
plt.plot(V_NN['Close'], label='Visa Closing Price History')
plt.savefig('V_4yr_data.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Prepare new dataframe with 2 dimensions

data = V_NN.sort_index(ascending=True, axis=0)
V_ma_NN = data.filter(['Date', 'Close'], axis=1)

V_ma_NN.head()
# Out:
#          Date   Close
# 0  2014-01-02  221.01
# 1  2014-01-03  221.16
# 2  2014-01-06  219.83
# 3  2014-01-07  221.51
# 4  2014-01-08  222.22

# %%
# Establish training and testing data ~60/40

V_NN_train = V_ma_NN[:1008]
V_NN_test = V_ma_NN[1008:]

# %%
# Fit data to model

V_ma_NN.shape, V_NN_train.shape, V_NN_test.shape
# Out:
# ((1345, 2), (1008, 2), (337, 2))

# %%
# Train for min and max

V_NN_train['Date'].min(), V_NN_train['Date'].max(), V_NN_test['Date'].min(), V_NN_test['Date'].max()
# Out:
# ('2014-01-02', '2018-01-02', '2018-01-03', '2019-05-07')

# %%
# Make the Predictions

predictions = []

for i in range(0,337):
    a = V_NN_train['Close'][len(V_NN_train)-337+i].sum() + sum(predictions)
    b = a/337
    predictions.append(b)

# %%
# Root Mean Square Error

rmse = np.sqrt(np.mean(np.power((np.array(V_NN_test['Close'])-predictions), 2)))
rmse
# Out:
# 136.92622681468137

# %%
# Check the model via plot

V_NN_test['Predictions'] = 0
V_NN_test['Predictions'] = predictions

plt.figure(figsize=(28,14))
plt.plot(V_NN_train['Close'])
plt.plot(V_NN_test[['Close', 'Predictions']])
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ...

# %%
# Long Term Short Memory: Set up

data = V_NN_df.sort_index(ascending=True, axis=0)
V_prep = pd.DataFrame(index=range(0,len(V_NN_df)), columns=['Date', 'Close'])

for i in range(0,len(data)):
    V_prep['Date'][i] = data['Date'][i]
    V_prep['Close'][i] = data['Close'][i]
    
V_prep.index = V_prep.Date
V_prep.drop('Date', axis=1, inplace=True)

dataset = V_prep.values

train = dataset[0:1258, :]
test = dataset[1258:, :]

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [],[]
for i in range(60, len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Create and fit data to LSTM network

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2)

inputs = V_prep[len(V_prep) - len(test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)

X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
# Out:
# WARNING:tensorflow:From C:\Users\Owner\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Owner\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
#  - 44s - loss: 0.0055

# %%
# Check results with RMSE

rmse = np.sqrt(np.mean(np.power((test-closing_price),2)))
rmse
# Out:
# 4.35822033449266

# %%
# Now plot

train = V_prep[:1258]
test = V_prep[1258:]

test['Predictions'] = closing_price

plt.figure(figsize=(28,14))
plt.plot(train['Close'])
plt.plot(test[['Close', 'Predictions']])
plt.savefig('V_predict_test.png')
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test.head()
# Out:
#              Close  Predictions
# Date
# 2019-01-02  132.92   126.241119
# 2019-01-03  128.13   127.332870
# 2019-01-04  133.65   127.531540
# 2019-01-07  136.06   128.210968
# 2019-01-08   136.8   129.389694

# %%
# Long Term Short Memory: Set up

data = V_NN_df.sort_index(ascending=True, axis=0)
V_prep = pd.DataFrame(index=range(0,len(V_NN_df)), columns=['Date', 'Close'])

for i in range(0,len(data)):
    V_prep['Date'][i] = data['Date'][i]
    V_prep['Close'][i] = data['Close'][i]
    
V_prep.index = V_prep.Date
V_prep.drop('Date', axis=1, inplace=True)

dataset = V_prep.values

train = dataset[0:1345, :]
test = dataset[1258:, :]

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [],[]
for i in range(60, len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))

# Create and fit data to LSTM network

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2)

inputs = V_prep[len(V_prep) - len(test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)

X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)

# Check results with RMSE

rmse = np.sqrt(np.mean(np.power((test-closing_price),2)))
rmse
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Epoch 1/1
#  - 48s - loss: 0.0069
# 5.0412509376336585

# %%
# Now plot

train = V_prep[:1258]
test = V_prep[1258:]

test['Predictions'] = closing_price

plt.figure(figsize=(28,14))
plt.plot(train['Close'])
plt.plot(test['Predictions'], 'g')
plt.savefig('V_predict_2019.png')
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test['Predictions'].head()

test['Predictions'].to_csv('resources/V_pred.csv')
